# %%
# %cd ..
# We load our model as we would any other model in our chosen framework:

import tensorflow.keras as keras
# (Make sure that you unzipped the archive provided by this repo first though.)
model = keras.models.load_model("models/tf_model")

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 112, 8, 8)]  0           []
#
#  inputconv (Conv2D)             (None, 256, 8, 8)    258304      ['input_1[0][0]']
#
#  re_lu (ReLU)                   (None, 256, 8, 8)    0           ['inputconv[0][0]']
#
#  block0/conv1 (Conv2D)          (None, 256, 8, 8)    590080      ['re_lu[0][0]']
#
#  block0/conv2 (Conv2D)          (None, 256, 8, 8)    590080      ['block0/conv1[0][0]']
#
#  add (Add)                      (None, 256, 8, 8)    0           ['block0/conv2[0][0]',
#                                                                   're_lu[0][0]']
#
#  re_lu_1 (ReLU)                 (None, 256, 8, 8)    0           ['add[0][0]']
#
#  block1/conv1 (Conv2D)          (None, 256, 8, 8)    590080      ['re_lu_1[0][0]']
#
#  block1/conv2 (Conv2D)          (None, 256, 8, 8)    590080      ['block1/conv1[0][0]']
#
#  add_1 (Add)                    (None, 256, 8, 8)    0           ['block1/conv2[0][0]',
#                                                                   're_lu_1[0][0]']
#
#  re_lu_2 (ReLU)                 (None, 256, 8, 8)    0           ['add_1[0][0]']
#
#  block2/conv1 (Conv2D)          (None, 256, 8, 8)    590080      ['re_lu_2[0][0]']
#
#  block2/conv2 (Conv2D)          (None, 256, 8, 8)    590080      ['block2/conv1[0][0]']
#
#  add_2 (Add)                    (None, 256, 8, 8)    0           ['block2/conv2[0][0]',
#                                                                   're_lu_2[0][0]']
#
#  re_lu_3 (ReLU)                 (None, 256, 8, 8)    0           ['add_2[0][0]']
#
#  block3/conv1 (Conv2D)          (None, 256, 8, 8)    590080      ['re_lu_3[0][0]']
#
#  block3/conv2 (Conv2D)          (None, 256, 8, 8)    590080      ['block3/conv1[0][0]']
#
#  add_3 (Add)                    (None, 256, 8, 8)    0           ['block3/conv2[0][0]',
#                                                                   're_lu_3[0][0]']
#
#  re_lu_4 (ReLU)                 (None, 256, 8, 8)    0           ['add_3[0][0]']
#
#  block4/conv1 (Conv2D)          (None, 256, 8, 8)    590080      ['re_lu_4[0][0]']
#
#  block4/conv2 (Conv2D)          (None, 256, 8, 8)    590080      ['block4/conv1[0][0]']
#
#  add_4 (Add)                    (None, 256, 8, 8)    0           ['block4/conv2[0][0]',
#                                                                   're_lu_4[0][0]']
#
#  re_lu_5 (ReLU)                 (None, 256, 8, 8)    0           ['add_4[0][0]']
#
#  block5/conv1 (Conv2D)          (None, 256, 8, 8)    590080      ['re_lu_5[0][0]']
#
#  block5/conv2 (Conv2D)          (None, 256, 8, 8)    590080      ['block5/conv1[0][0]']
#
#  add_5 (Add)                    (None, 256, 8, 8)    0           ['block5/conv2[0][0]',
#                                                                   're_lu_5[0][0]']
#
#  re_lu_6 (ReLU)                 (None, 256, 8, 8)    0           ['add_5[0][0]']
#
#  block6/conv1 (Conv2D)          (None, 256, 8, 8)    590080      ['re_lu_6[0][0]']
#
#  block6/conv2 (Conv2D)          (None, 256, 8, 8)    590080      ['block6/conv1[0][0]']
#
#  add_6 (Add)                    (None, 256, 8, 8)    0           ['block6/conv2[0][0]',
#                                                                   're_lu_6[0][0]']
#
#  re_lu_7 (ReLU)                 (None, 256, 8, 8)    0           ['add_6[0][0]']
#
#  block7/conv1 (Conv2D)          (None, 256, 8, 8)    590080      ['re_lu_7[0][0]']
#
#  block7/conv2 (Conv2D)          (None, 256, 8, 8)    590080      ['block7/conv1[0][0]']
#
#  add_7 (Add)                    (None, 256, 8, 8)    0           ['block7/conv2[0][0]',
#                                                                   're_lu_7[0][0]']
#
#  re_lu_8 (ReLU)                 (None, 256, 8, 8)    0           ['add_7[0][0]']
#
#  block8/conv1 (Conv2D)          (None, 256, 8, 8)    590080      ['re_lu_8[0][0]']
#
#  block8/conv2 (Conv2D)          (None, 256, 8, 8)    590080      ['block8/conv1[0][0]']
#
#  add_8 (Add)                    (None, 256, 8, 8)    0           ['block8/conv2[0][0]',
#                                                                   're_lu_8[0][0]']
#
#  re_lu_9 (ReLU)                 (None, 256, 8, 8)    0           ['add_8[0][0]']
#
#  block9/conv1 (Conv2D)          (None, 256, 8, 8)    590080      ['re_lu_9[0][0]']
#
#  block9/conv2 (Conv2D)          (None, 256, 8, 8)    590080      ['block9/conv1[0][0]']
#
#  add_9 (Add)                    (None, 256, 8, 8)    0           ['block9/conv2[0][0]',
#                                                                   're_lu_9[0][0]']
#
#  re_lu_10 (ReLU)                (None, 256, 8, 8)    0           ['add_9[0][0]']
#
#  block10/conv1 (Conv2D)         (None, 256, 8, 8)    590080      ['re_lu_10[0][0]']
#
#  block10/conv2 (Conv2D)         (None, 256, 8, 8)    590080      ['block10/conv1[0][0]']
#
#  add_10 (Add)                   (None, 256, 8, 8)    0           ['block10/conv2[0][0]',
#                                                                   're_lu_10[0][0]']
#
#  re_lu_11 (ReLU)                (None, 256, 8, 8)    0           ['add_10[0][0]']
#
#  block11/conv1 (Conv2D)         (None, 256, 8, 8)    590080      ['re_lu_11[0][0]']
#
#  block11/conv2 (Conv2D)         (None, 256, 8, 8)    590080      ['block11/conv1[0][0]']
#
#  add_11 (Add)                   (None, 256, 8, 8)    0           ['block11/conv2[0][0]',
#                                                                   're_lu_11[0][0]']
#
#  re_lu_12 (ReLU)                (None, 256, 8, 8)    0           ['add_11[0][0]']
#
#  block12/conv1 (Conv2D)         (None, 256, 8, 8)    590080      ['re_lu_12[0][0]']
#
#  block12/conv2 (Conv2D)         (None, 256, 8, 8)    590080      ['block12/conv1[0][0]']
#
#  add_12 (Add)                   (None, 256, 8, 8)    0           ['block12/conv2[0][0]',
#                                                                   're_lu_12[0][0]']
#
#  re_lu_13 (ReLU)                (None, 256, 8, 8)    0           ['add_12[0][0]']
#
#  block13/conv1 (Conv2D)         (None, 256, 8, 8)    590080      ['re_lu_13[0][0]']
#
#  block13/conv2 (Conv2D)         (None, 256, 8, 8)    590080      ['block13/conv1[0][0]']
#
#  add_13 (Add)                   (None, 256, 8, 8)    0           ['block13/conv2[0][0]',
#                                                                   're_lu_13[0][0]']
#
#  re_lu_14 (ReLU)                (None, 256, 8, 8)    0           ['add_13[0][0]']
#
#  block14/conv1 (Conv2D)         (None, 256, 8, 8)    590080      ['re_lu_14[0][0]']
#
#  block14/conv2 (Conv2D)         (None, 256, 8, 8)    590080      ['block14/conv1[0][0]']
#
#  add_14 (Add)                   (None, 256, 8, 8)    0           ['block14/conv2[0][0]',
#                                                                   're_lu_14[0][0]']
#
#  re_lu_15 (ReLU)                (None, 256, 8, 8)    0           ['add_14[0][0]']
#
#  block15/conv1 (Conv2D)         (None, 256, 8, 8)    590080      ['re_lu_15[0][0]']
#
#  block15/conv2 (Conv2D)         (None, 256, 8, 8)    590080      ['block15/conv1[0][0]']
#
#  add_15 (Add)                   (None, 256, 8, 8)    0           ['block15/conv2[0][0]',
#                                                                   're_lu_15[0][0]']
#
#  re_lu_16 (ReLU)                (None, 256, 8, 8)    0           ['add_15[0][0]']
#
#  block16/conv1 (Conv2D)         (None, 256, 8, 8)    590080      ['re_lu_16[0][0]']
#
#  block16/conv2 (Conv2D)         (None, 256, 8, 8)    590080      ['block16/conv1[0][0]']
#
#  add_16 (Add)                   (None, 256, 8, 8)    0           ['block16/conv2[0][0]',
#                                                                   're_lu_16[0][0]']
#
#  re_lu_17 (ReLU)                (None, 256, 8, 8)    0           ['add_16[0][0]']
#
#  block17/conv1 (Conv2D)         (None, 256, 8, 8)    590080      ['re_lu_17[0][0]']
#
#  block17/conv2 (Conv2D)         (None, 256, 8, 8)    590080      ['block17/conv1[0][0]']
#
#  add_17 (Add)                   (None, 256, 8, 8)    0           ['block17/conv2[0][0]',
#                                                                   're_lu_17[0][0]']
#
#  re_lu_18 (ReLU)                (None, 256, 8, 8)    0           ['add_17[0][0]']
#
#  block18/conv1 (Conv2D)         (None, 256, 8, 8)    590080      ['re_lu_18[0][0]']
#
#  block18/conv2 (Conv2D)         (None, 256, 8, 8)    590080      ['block18/conv1[0][0]']
#
#  add_18 (Add)                   (None, 256, 8, 8)    0           ['block18/conv2[0][0]',
#                                                                   're_lu_18[0][0]']
#
#  re_lu_19 (ReLU)                (None, 256, 8, 8)    0           ['add_18[0][0]']
#
#  block19/conv1 (Conv2D)         (None, 256, 8, 8)    590080      ['re_lu_19[0][0]']
#
#  block19/conv2 (Conv2D)         (None, 256, 8, 8)    590080      ['block19/conv1[0][0]']
#
#  add_19 (Add)                   (None, 256, 8, 8)    0           ['block19/conv2[0][0]',
#                                                                   're_lu_19[0][0]']
#
#  re_lu_20 (ReLU)                (None, 256, 8, 8)    0           ['add_19[0][0]']
#
#  value_conv (Conv2D)            (None, 32, 8, 8)     8224        ['re_lu_20[0][0]']
#
#  policy_conv (Conv2D)           (None, 32, 8, 8)     8224        ['re_lu_20[0][0]']
#
#  flatten_1 (Flatten)            (None, 2048)         0           ['value_conv[0][0]']
#
#  flatten (Flatten)              (None, 2048)         0           ['policy_conv[0][0]']
#
#  value_dense_1 (Dense)          (None, 128)          262272      ['flatten_1[0][0]']
#
#  policy_dense (Dense)           (None, 1858)         3807042     ['flatten[0][0]']
#
#  value_output (Dense)           (None, 1)            129         ['value_dense_1[0][0]']
#
# ==================================================================================================
# Total params: 27,947,395
# Trainable params: 27,947,395
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# And the world is your oyster!
